# %%
from io import StringIO
from bs4 import BeautifulSoup
from tika import parser
import re

file_path = "Books Index for Phrases/Wooldridge - Introductory Econometrics (A Modern Approach) [Cengage 5th Ed - 2013].pdf"

file_data = []
_buffer = StringIO()
data = parser.from_file(file_path, xmlContent=True)
xhtml_data = BeautifulSoup(data['content'])
for page, content in enumerate(xhtml_data.find_all('div', attrs={'class': 'page'})):
    print('Parsing page {} of pdf file...'.format(page+1))
    _buffer = StringIO()
    _buffer.write(str(content))
    parsed_content = parser.from_buffer(_buffer.getvalue())
    _buffer.truncate()
    file_data.append({'id': 'page_'+str(page+1), 'content': parsed_content['content']})
# Out:
# Parsing page 1 of pdf file...
# Parsing page 2 of pdf file...
# Parsing page 3 of pdf file...
# Parsing page 4 of pdf file...
# Parsing page 5 of pdf file...
# Parsing page 6 of pdf file...
# Parsing page 7 of pdf file...
# Parsing page 8 of pdf file...
# Parsing page 9 of pdf file...
# Parsing page 10 of pdf file...
# Parsing page 11 of pdf file...
# Parsing page 12 of pdf file...
# Parsing page 13 of pdf file...
# Parsing page 14 of pdf file...
# Parsing page 15 of pdf file...
# Parsing page 16 of pdf file...
# Parsing page 17 of pdf file...
# Parsing page 18 of pdf file...
# Parsing page 19 of pdf file...
# Parsing page 20 of pdf file...

# %%
START = "2SLS. See two stage least squares"
END = "assumptions"
PAGE_NUM = '862'

# %%
text = file_data[0]['content']

# %%
page_num_regex = re.compile(r', \d{1,3}')
# re.search(page_num_regex, 'adaptive expectations, 390, 392')
page_num_regex.sub('', 'adaptive expectations, 390, 392')
# Out:
# 'adaptive expectations'

# %%
page_num_regex = re.compile(r', \d{1,3}–\d{1,3}')
page_num_regex.sub('', 'adjusted R-squareds, 202–205, 414')
# Out:
# 'adjusted R-squareds, 414'

# %%
page_num_regex = re.compile(r'^\d{1,3}–\d{1,3}')
page_num_regex.sub('', '349–352')
# Out:
# ''

# %%
page_num_regex = re.compile(r'^\d{1,3}–\d{1,3}')
page_num_regex.sub('', ' 349–352')
# Out:
# ' 349–352'

# %%
see_regex = re.compile(r'\. See.+')
see_regex.sub('','2SLS. See two stage least squares')
# Out:
# '2SLS'

# %%
see_regex = re.compile(r'\. See.+')
see_regex.sub('','achievement test scores. See college GPA')
# Out:
# 'achievement test scores'

# %%
res = []

for line in text.split('\n'):
    if START < line.lower() < END:
        if len(line) == 1 or line == 'Index' or line == PAGE_NUM:
            continue

        # clean page number
        page_num_regex_2 = re.compile(r', \d{1,3}–\d{1,3}')
        line = page_num_regex_2.sub('', line)

        page_num_regex_1 = re.compile(r', \d{1,3}')
        line = page_num_regex_1.sub('', line)

        page_num_regex_3 = re.compile(r'^\d{1,3}–\d{1,3}')
        line = page_num_regex_3.sub('', line)

        # remove See ...
        see_regex = re.compile(r'\. See.+')
        line = see_regex.sub('', line)

        if line:
            res.append(line)

# %%
res
# Out:
# ['2SLS',
#  '401(k) plans',
#  'ability and wage',
#  'achievement test scores',
#  'adaptive expectations',
#  'adjusted R-squareds',
#  'AFDC participation',
#  'age',
#  'aggregate consumption function',
#  'air pollution and housing prices',
#  'airline and reservations',
#  'alcohol drinking',
#  'alternative hypotheses',
#  'antidumping filings and chemical imports',
#  'AR(3) serial correlation',
#  'apples, ecolabeled',
#  'AR(1) models, consistency example',
#  'AR(1) serial correlation',
#  'AR(2) models',
#  'ARCH model',
#  'AR(q) serial correlation',
#  'arrests',
#  'ASCII files',
#  'assumption']

# %%
def extract_phrase(start_phrase, end_phrase, page_num, text): 

    res = []

    for line in text.split('\n'):
        if start_phrase.lower() <= line.lower() <= end_phrase.lower() or start_phrase.lower() >= line.lower() >= end_phrase.lower():
            if len(line) == 1 or line == 'Index' or line == page_num or len(line) > 100:
                continue

            # clean page number
            page_num_regex_2 = re.compile(r', \d{1,3}–\d{1,3}')
            line = page_num_regex_2.sub('', line)

            page_num_regex_1 = re.compile(r', \d{1,3}')
            line = page_num_regex_1.sub('', line)

            page_num_regex_3 = re.compile(r'^\d{1,3}–\d{1,3}')
            line = page_num_regex_3.sub('', line)

            # remove See ...
            see_regex = re.compile(r'\. See.+')
            line = see_regex.sub('', line)
                
            if line:
                res.append(line)

    return res

# %%
extract_phrase(start_phrase='2SLS. See two stage least squares', 
              end_phrase="assumptions", page_num="862", text=file_data[0]['content'])
# Out:
# ['2SLS',
#  '401(k) plans',
#  'ability and wage',
#  'achievement test scores',
#  'adaptive expectations',
#  'adjusted R-squareds',
#  'AFDC participation',
#  'age',
#  'aggregate consumption function',
#  'air pollution and housing prices',
#  'airline and reservations',
#  'alcohol drinking',
#  'alternative hypotheses',
#  'antidumping filings and chemical imports',
#  'AR(3) serial correlation',
#  'apples, ecolabeled',
#  'AR(1) models, consistency example',
#  'AR(1) serial correlation',
#  'AR(2) models',
#  'ARCH model',
#  'AR(q) serial correlation',
#  'arrests',
#  'ASCII files',
#  'assumptions',
#  'assumption']

# %%
extract_phrase(start_phrase='asymptotic bias', 
              end_phrase="chemical imports. See antidumping filings and", page_num="863", text=file_data[1]['content'])
# Out:
# ['bias',
#  'attenuation',
#  'biased estimators',
#  'biased toward zero',
#  'binary response models',
#  'binary variables',
#  'binomial distribution',
#  'birth weight',
#  'asymptotic standard error',
#  'bivariate linear regression model',
#  'BLUE (best linear unbiased estimator)',
#  'bootstrapping',
#  'Breusch-Godfrey test',
#  'Breusch-Pagan test',
#  'calculus, differential',
#  'campus crimes, t test',
#  'causality',
#  'cdf (cumulative distribution functions)',
#  'censored regression models',
#  'Center for Research in Security Prices',
#  'central limit theorem',
#  'CEO salaries',
#  'ceteris paribus',
#  'chemical firms, nonnested models',
#  'chemical imports',
#  'asymptotic bias, deriving',
#  'asymptotic confidence interval',
#  'asymptotic efficiency of OLS',
#  'asymptotic normality of estimators, in general,  ',
#  'asymptotic normality of OLS',
#  'asymptotic sample properties of estimators,  ',
#  'asymptotic standard errors',
#  'asymptotic t statistics',
#  'asymptotically uncorrelated sequences',
#  'asymptotics, OLS',
#  'attenuation bias',
#  'attrition',
#  'augmented Dickey-Fuller test',
#  'autocorrelation',
#  'autoregressive conditional heteroskedacity (ARCH) ',
#  'autoregressive model of order two [AR(2)]',
#  'autoregressive process of order one',
#  'auxiliary regression',
#  'average, using summation operator',
#  'average marginal effect (AME)',
#  'average partial effect (APE)',
#  'average treatment effect',
#  'balanced panel',
#  'barium chloride',
#  'chemical imports',
#  'base group',
#  'base period and value',
#  'baseball players’ salaries',
#  'Becker, Gary',
#  'beer',
#  'benchmark group',
#  'Bernoulli random variables',
#  'best linear unbiased estimator (BLUE)',
#  'beta coefficients',
#  'between estimators']

# %%
input_start = ['2SLS', 'asymptotic bias, deriving', 'chi-square distribution', 'criminologists', 'economic models', 'exogenous explanatory variables', 'firm sales', 'heteroskedasticity', 'independently pooled cross sections', 'Lagrange multiplier (LM) statistics', 'measurement error', 'OLS asymptotics', 'Panel Study of Income Dynamics', 'quadratic form for matrices', 'returns on equity and CEO salaries', 'serial correlation-robust standard errors, 431–434', 'stepwise regression, 686', 'theoretical framework, 687', 'unbalanced panels, 491–492', 'Wald test/statistics, 588–589, 598, 818', ]
input_end = ['assumptions', 'chemical imports. See antidumping filings and', 'crimes. See also arrests', 'economic growth and government policies', 'exclusion restrictions', 'finite sample properties', 'heterogeneity bias', 'independent variables', 'lagged explanatory variables', 'mean squared error (MSE)', 'OLS (ordinary least squares). See also', 'panel data', 'p-values', 'retrospective data, 2', 'serial correlation', 'statistics. See also hypothesis testing', 'theorems', 'unanticipated inflation, 390', 'wages. See also CEO salaries; income; minimum', 'zero-one variables, 227. See also qualitative']
input_page_num = [str(862 + i) for i in range(20)]
# input_text = [file_data[i]['content'] if i == 0 else file_data[i]['content'].replace(file_data[i-1]['content'], '') for i in range(20) ]
input_text = [file_data[i]['content'] for i in range(20) ]

# %%
import pandas as pd
pd.DataFrame({'page': input_page_num, 'start': input_start, 'end': input_end})
# Out:
#    page                                              start  \
# 0   862                                               2SLS
# 1   863                          asymptotic bias, deriving
# 2   864                            chi-square distribution
# 3   865                                     criminologists
# 4   866                                    economic models
# 5   867                    exogenous explanatory variables
# 6   868                                         firm sales
# 7   869                                 heteroskedasticity
# 8   870                independently pooled cross sections
# 9   871                Lagrange multiplier (LM) statistics
# 10  872                                  measurement error
# 11  873                                    OLS asymptotics
# 12  874                     Panel Study of Income Dynamics
# 13  875                        quadratic form for matrices
# 14  876                 returns on equity and CEO salaries
# 15  877  serial correlation-robust standard errors, 431...
# 16  878                           stepwise regression, 686
# 17  879                         theoretical framework, 687
# 18  880                         unbalanced panels, 491–492
# 19  881            Wald test/statistics, 588–589, 598, 818
#
#                                               end
# 0                                     assumptions
# 1   chemical imports. See antidumping filings and
# 2                        crimes. See also arrests
# 3         economic growth and government policies
# 4                          exclusion restrictions
# 5                        finite sample properties
# 6                              heterogeneity bias
# 7                           independent variables
# 8                    lagged explanatory variables
# 9                        mean squared error (MSE)
# 10         OLS (ordinary least squares). See also
# 11                                     panel data
# 12                                       p-values
# 13                          retrospective data, 2
# 14                             serial correlation
# 15        statistics. See also hypothesis testing
# 16                                       theorems
# 17                   unanticipated inflation, 390
# 18  wages. See also CEO salaries; income; minimum
# 19  zero-one variables, 227. See also qualitative

# %%
print(input_text[10])
# Out:
# municipal bond interest rates, 237–238
# murder rates
#
#
# SEM, 557
# static Phillips curve, 346
#
#
# n
# natural experiments, 457, 521
# natural logarithms, 712–715. See also logarithms
# netting out, 78
# no perfect collinearity assumption
#
#
# for multiple linear regressions, 84–86, 87
# for OLS in matrix form, 810
# for time series regressions, 350, 385
#
#
# no serial correlation assumption. See also serial
# correlation
#
#
# for 2SLS, 553
# for OLS in matrix form, 811
# for time series regressions, 353–354, 387–388
#
#
# nominal dollars, 360
# nonexperimental data, 2
# nonlinear functions, 710–716
# nonlinearities, incorporating in simple regressions,
#
#
# 41–44
# nonnested models
#
#
# choosing between, 203–205
# functional form misspecification and, 307–308
#
#
# nonrandom samples, 324–326, 615
# nonstationary time series processes, 381–382
# normal distribution, 745–749
# normal sampling distributions
#
#
# for multiple linear regressions, 120–121
# for time series regressions, 355–356
#
#
# normality assumption
# for multiple linear regressions, 118–121
# for time series regressions, 355
#
#
# normality of errors assumption, 813
# normality of estimators in general, asymptotic,
#
#
# 766–767
# normality of OLS, asymptotic
#
#
# in multiple regressions, 173–178, 185
# in time series regressions, 387–391
#
#
# n-R-squared statistic, 178–181
# null hypothesis, 122–123, 778. See also hypotheses
#
#
# O
# observational data, 2
# OLS (ordinary least squares). See also
#
#
# heteroskedasticity; panel data; predictions; other
# OLS entries
#
#
# measurement error
# IV solutions to, 532–534
# properties of OLS under, 317–323
#
#
# measures of association, 737–739
# measures of central tendency, 730–734
# measures of variability, 734–737
# median, 704, 733–734
# men, return to education, 518–519
# method of moments approach, 28, 768–769
# micronumerosity, 96
# military personnel survey, oversampling in, 326
# minimum variance unbiased estimators, 119, 769, 815
# minimum wages
#
#
# employment/unemployment and
# AR(1) serial correlation, testing for, 420–421
# causality, 15
# detrending, 369–370
# logarithmic form, 356–357
# SC-robust standard error, 434
#
#
# in Puerto Rico, effects of, 8–9
# minorities and loans. See loan approval rates
# missing data, 324
# misspecification
#
#
# in empirical projects, 684–685
# functional form, 304–308
# unbiasedness and, 88–92
# variances, 98–99
#
#
# motherhood, teenage, 499–500
# moving average process of order one, 383
# MSE (mean squared error), 763
# multicollinearity
#
#
# 2SLS and, 530–531
# among explanatory variables, 324
# main discussion, 94–98
#
#
# multiple hypotheses tests, 144
# multiple regression analysis. See also data issues;
#
#
# estimation and estimators; heteroskedasticity;
# hypotheses; OLS (ordinary least squares);
# predictions; R-squareds
#
#
# adding regressors to reduce error variance, 206–207
# advantages over simple regression, 68–72
# confidence intervals, 138–140
# functional forms. See under functional forms
# over controlling, 205–206
# with qualitative information. See under qualitative
#
#
# information
# multiple restrictions, 144
# multiple-step-ahead forecasts, 660–662
# multiplicative measurement error, 319
# multivariate normal distribution, 804
#
#
# 872 Index
#
#
# Copyright 2012 Cengage Learning. All Rights Reserved. May not be copied, scanned, or duplicated, in whole or in part. Due to electronic rights, some third party content may be suppressed from the eBook and/or eChapter(s). Editorial review has
# deemed that any suppressed content does not materially affect the overall learning experience. Cengage Learning reserves the right to remove additional content at any time if subsequent rights restrictions require it.

# %%
total_extracted_key_phrase = []
for i in range(20):
    # print(extract_phrase(start_phrase=input_start[i], 
    #                            end_phrase=input_end[i], 
    #                            page_num=input_page_num[i], 
    #                            text=input_text[i]))
    extracted_key_phrase_by_page = extract_phrase(start_phrase=input_start[i], 
                                        end_phrase=input_end[i], 
                                        page_num=input_page_num[i], 
                                        text=input_text[i])
    total_extracted_key_phrase += extracted_key_phrase_by_page
    print('{keyword_num} keywords extracted from page {page_num}'.format(keyword_num=len(extracted_key_phrase_by_page), page_num=input_page_num[i]))
# Out:
# 25 keywords extracted from page 862
# 60 keywords extracted from page 863
# 58 keywords extracted from page 864
# 55 keywords extracted from page 865
# 29 keywords extracted from page 866
# 34 keywords extracted from page 867
# 46 keywords extracted from page 868
# 38 keywords extracted from page 869
# 46 keywords extracted from page 870
# 53 keywords extracted from page 871
# 47 keywords extracted from page 872
# 27 keywords extracted from page 873
# 2 keywords extracted from page 874
# 49 keywords extracted from page 875
# 38 keywords extracted from page 876
# 38 keywords extracted from page 877
# 37 keywords extracted from page 878
# 28 keywords extracted from page 879
# 28 keywords extracted from page 880
# 30 keywords extracted from page 881

# %%
sorted(total_extracted_key_phrase)
# Out:
# ['2SLS',
#  '401(k) plans',
#  'AFDC participation',
#  'AR(1) models, consistency example',
#  'AR(1) serial correlation',
#  'AR(2) models',
#  'AR(3) serial correlation',
#  'AR(q) serial correlation',
#  'ARCH model',
#  'ASCII files',
#  'BLUE (best linear unbiased estimator)',
#  'Becker, Gary',
#  'Bernoulli random variables',
#  'Breusch-Godfrey test',
#  'Breusch-Pagan test',
#  'CEO salaries',
#  'CPI (consumer price index)',
#  'Center for Research in Security Prices',
#  'Chow tests',
#  'Cochrane-Orcutt (CO) estimation',
#  'Compustat',
#  'Davidson-MacKinnon test',
#  'Dickey-Fuller test',
#  'Durbin-Watson test',
#  'EMH',
#  'Eagle-Granger test',
#  'EconLit',
#  'Engle-Granger two-step procedure',
#  'Excel',
#  'F and t statistics',
#  'F distribution',
#  'F statistics',
#  'F tests',
#  'FDL (finite distributed lag) models, ',
#  'FDL model',
#  'Federal Bureau of Investigation',
#  'GDL (geometric distributed lag)',
#  'GDP',
#  'GLS estimators',
#  'GPA',
#  'Gauss-Markov Theorem',
#  'Gauss-Markov assumptions',
#  'Goldberger, Arthur',
#  'Google Scholar',
#  'Granger causality',
#  'Granger, Clive W. J.',
#  'HAC standard errors',
#  'Hartford School District',
#  'Hausman test',
#  'Head Start participation',
#  'Heckit method',
#  'I(0) and I(1) processes',
#  'IDL (infinite distributed lag models)',
#  'IIP (index of industrial production)',
#  'IQ',
#  'IV',
#  'JEL (Journal of Economic Literature)',
#  'Journal of Economic Literature (JEL)',
#  'Koyck distributed lag',
#  'LAD (least absolute deviations) estimation',
#  'LDV',
#  'LM statistics',
#  'LPM',
#  'LRP (long-run propensity)',
#  'Lagrange multiplier (LM) statistics',
#  'MAE (mean absolute error)',
#  'MSE (mean squared error)',
#  'OLS asymptotics',
#  'OLS estimators',
#  'OLS in matrix form',
#  'OLS intercept estimates, defined',
#  'OLS regression line',
#  'OLS slope estimates, defined',
#  'R&D and sales',
#  'R2j',
#  'RDL (rational distributed lag models)',
#  'REST (regression specification error test)',
#  'RMSE (root mean squared error)',
#  'SEM',
#  'SRF (sample regression function)',
#  'SSE (explained sum of squares)',
#  'SSR (residual sum of squares)',
#  'SST (total sum of squares)',
#  'SSTj (total sample variation in xj)',
#  'Social Sciences Citation Index',
#  'Survey of Consumer Finances',
#  'T-bill rates',
#  'Tobit model',
#  'Type I/II error',
#  'VAR model',
#  'Wald test/statistics',
#  'White test for heteroskedasticity',
#  'ability and wage',
#  'achievement test scores',
#  'adaptive expectations',
#  'adjusted R-squareds',
#  'age',
#  'aggregate consumption function',
#  'air pollution and housing prices',
#  'airline and reservations',
#  'alcohol drinking',
#  'alternative hypotheses',
#  'antidumping filings and chemical imports',
#  'apples, ecolabeled',
#  'arrests',
#  'assumption',
#  'assumptions',
#  'asymptotic bias, deriving',
#  'asymptotic confidence interval',
#  'asymptotic efficiency of OLS',
#  'asymptotic normality of OLS',
#  'asymptotic normality of estimators, in general,  ',
#  'asymptotic sample properties of estimators,  ',
#  'asymptotic standard error',
#  'asymptotic standard errors',
#  'asymptotic t statistics',
#  'asymptotically uncorrelated sequences',
#  'asymptotics, OLS',
#  'attenuation',
#  'attenuation bias',
#  'attrition',
#  'augmented Dickey-Fuller test',
#  'autocorrelation',
#  'autoregressive conditional heteroskedacity (ARCH) ',
#  'autoregressive model of order two [AR(2)]',
#  'autoregressive process of order one',
#  'auxiliary regression',
#  'average marginal effect (AME)',
#  'average partial effect (APE)',
#  'average treatment effect',
#  'average, using summation operator',
#  'balanced panel',
#  'barium chloride',
#  'base group',
#  'base period and value',
#  'baseball players’ salaries',
#  'beer',
#  'benchmark group',
#  'best linear unbiased estimator (BLUE)',
#  'beta coefficients',
#  'between estimators',
#  'bias',
#  'biased estimators',
#  'biased toward zero',
#  'binary response models',
#  'binary variables',
#  'binomial distribution',
#  'birth weight',
#  'bivariate linear regression model',
#  'bootstrapping',
#  'calculus, differential',
#  'campus crimes, t test',
#  'causality',
#  'cdf (cumulative distribution functions)',
#  'censored regression models',
#  'central limit theorem',
#  'ceteris paribus',
#  'chemical firms, nonnested models',
#  'chemical imports',
#  'chemical imports',
#  'chi-square distribution',
#  'cigarettes',
#  'city crimes',
#  'classical errors-in-variables (CEV)',
#  'classical linear model (CLM) assumptions',
#  'clear-up rate, distributed lag estimation',
#  'clusters',
#  'coefficient of determination',
#  'cointegration',
#  'college GPA',
#  'college GPA and',
#  'college admission, omitting unobservables',
#  'college proximity, as IV for education',
#  'colleges, junior vs. four-year',
#  'collinearity, perfect',
#  'column vectors',
#  'commute time and freeway width',
#  'compact discs, demand for',
#  'comparison of simple and multiple regression  ',
#  'composite error',
#  'composite error term',
#  'computer ownership',
#  'computer usage and wages',
#  'computers, grants to buy',
#  'conceptual framework',
#  'conditional distributions',
#  'conditional expectations',
#  'conditional forecasts',
#  'conditional median',
#  'conditional variances',
#  'confidence intervals',
#  'consistency of OLS',
#  'consistency of estimators, in general',
#  'consistent tests',
#  'constant dollars',
#  'constant elasticity model',
#  'constant terms',
#  'consumer price index (CPI)',
#  'consumption',
#  'contemporaneously exogenous variables',
#  'continuous random variables',
#  'control group',
#  'control variables',
#  'corner solution responses',
#  'corrected R-squareds',
#  'correlated random effects',
#  'correlation',
#  'correlation coefficients',
#  'count variables',
#  'county crimes, multi-year panel data',
#  'covariance stationary processes',
#  'covariances',
#  'covariates',
#  'crimes',
#  'criminologists',
#  'critical values',
#  'crop yields and fertilizers',
#  'cross-sectional data',
#  'cumulative areas under standard normal distribution, ',
#  'cumulative distribution functions (cdf)',
#  'cumulative effect',
#  'current dollars',
#  'cyclical unemployment',
#  'data',
#  'data collection',
#  'data frequency',
#  'data issues',
#  'data mining',
#  'data scaling, effects on OLS statistics',
#  'data sources',
#  'deficits',
#  'defined',
#  'defined',
#  'degrees of freedom (df)',
#  'demand equations',
#  'dependent variables',
#  'derivation of equation',
#  'derivation of first order conditions in equation',
#  'derivatives',
#  'descriptive statistics',
#  'detrending',
#  'diagonal matrices',
#  'difference in slopes',
#  'difference-in-differences estimator',
#  'difference-stationary processes',
#  'differencing',
#  'differential calculus',
#  'diminishing marginal effects',
#  'discrete random variables',
#  'discussions',
#  'disturbance terms',
#  'disturbance variances',
#  'downward bias',
#  'drug usage',
#  'drunk driving laws and fatalities',
#  'dummy variables',
#  'duration analysis',
#  'dynamically complete models',
#  'earlier data, use of',
#  'earnings of veterans, IV estimation',
#  'econometric analysis in projects',
#  'econometric model of',
#  'econometric models',
#  'econometrics',
#  'economic models',
#  'economic vs. statistical significance',
#  'economists, types of',
#  'education',
#  'efficiency',
#  'efficient markets hypothesis (EMH)',
#  'elasticity',
#  'elections',
#  'empirical analysis',
#  'employment and unemployment',
#  'endogenous explanatory variables',
#  'endogenous sample selection',
#  'enrollment, t test',
#  'enterprise zones',
#  'enterprise zones and',
#  'error correction models',
#  'error terms',
#  'error variances',
#  'errors-in-variables problem',
#  'estimated GLS',
#  'estimating',
#  'estimating average rate',
#  'estimation and estimators',
#  'event studies',
#  'excluding relevant variables',
#  'exclusion restrictions',
#  'exogenous explanatory variables',
#  'exogenous instrumental variables',
#  'exogenous sample selection',
#  'expectations augmented Phillips curve',
#  'expectations hypothesis',
#  'expected values',
#  'experience',
#  'experimental data',
#  'experimental group',
#  'experiments, defined',
#  'explained sum of squares (SSE)',
#  'explained variables',
#  'explanatory variables',
#  'exponential function',
#  'exponential smoothing',
#  'exponential trends',
#  'exponentiating',
#  'family income',
#  'farmers and pesticide usage',
#  'feasible GLS',
#  'fertility rate',
#  'fertility studies, with discrete dependent variables,  ',
#  'fertilizers',
#  'final exam scores',
#  'financial wealth',
#  'finite distributed lag (FDL) models,  ',
#  'finite sample properties',
#  'firm sales',
#  'first differencing',
#  'first differencing vs.',
#  'first order autocorrelation',
#  'first order conditions',
#  'first-differenced equations',
#  'fitted values',
#  'fixed effects',
#  'fixed effects vs.',
#  'for AR(1) models',
#  'for OLS in matrix form',
#  'for multiple linear regressions',
#  'for multiple linear regressions',
#  'for simple linear regressions',
#  'for time series regressions',
#  'forecast intervals',
#  'forecasting',
#  'free throw shooting',
#  'freeway width and commute time',
#  'frequency distributions(k) plans',
#  'frequency, data',
#  'functional forms',
#  'gender',
#  'generalized least squares (GLS) estimators',
#  'geometric distributed lag (GDL)',
#  'goodness-of-fit',
#  'government policies',
#  'government policies and',
#  'gross domestic product (GDP)',
#  'growth rate',
#  'gun control laws',
#  'heteroskedasticity',
#  'heteroskedasticity',
#  'heteroskedasticity-robust procedures',
#  'high school and college GPAs',
#  'highly persistent time series',
#  'histogram(k) plan participation',
#  'homoskedasticity',
#  'hourly wages',
#  'housing expenditure and',
#  'housing prices and expenditures',
#  'hypotheses',
#  'hypothesis testing',
#  'idempotent matrices',
#  'identification',
#  'identity matrices',
#  'idiosyncratic error',
#  'impact propensity/multiplier',
#  'in logit and probit models',
#  'in matrix form, Wald statistics for',
#  'in misspecified models',
#  'in systems with three or more equations',
#  'in systems with two equations',
#  'in time series regressions',
#  'in wage equation',
#  'incidental truncation',
#  'incinerators and',
#  'incinerators and housing prices',
#  'including irrelevant variables',
#  'income',
#  'income and',
#  'inconsistency in OLS',
#  'inconsistency in OLS',
#  'inconsistency in OLS, deriving',
#  'inconsistent estimators',
#  'independence, joint distributions and',
#  'independently pooled cross sections',
#  'index numbers',
#  'industrial production, index of (IIP)',
#  'infant mortality rates, outliers',
#  'inference',
#  'inference under CLM assumptions',
#  'infinite distributed lag models',
#  'inflation',
#  'inflation, deficits, and',
#  'influential observations',
#  'information set',
#  'instrumental variables',
#  'integrated of order zero/one processes',
#  'integrated processes, forecasting',
#  'interaction effect',
#  'interaction terms',
#  'intercept shifts',
#  'intercepts',
#  'interest rates',
#  'interest rates and',
#  'interval estimation',
#  'intervals',
#  'inverse Mills ratio',
#  'inverse of matrix',
#  'irrelevant variables, including',
#  'job training',
#  'joint distributions',
#  'joint hypotheses tests',
#  'jointly statistically significant/insignificant',
#  'journals listing',
#  'junior colleges vs. universities',
#  'just identified equations',
#  'kurtosis',
#  'labor economists',
#  'labor force',
#  'labor supply and demand',
#  'labor supply function',
#  'lag distribution',
#  'lagged dependent variables',
#  'lagged endogenous variables',
#  'land quality and fertilizers',
#  'large sample properties',
#  'latent variable models',
#  'law enforcement',
#  'law of iterated expectations',
#  'law of large numbers',
#  'law school rankings',
#  'leads and lags estimators',
#  'least absolute deviations (LAD) estimation',
#  'least squares estimator',
#  'likelihood ratio statistic',
#  'limited dependent variables',
#  'linear functions',
#  'linear in parameters assumption',
#  'linear independence',
#  'linear independence and rank of',
#  'linear probability model (LPM)',
#  'linear regression model',
#  'linear relationship among independent variables',
#  'linear time trends',
#  'linearity and weak dependence assumption',
#  'literature review',
#  'loan approval rates',
#  'log-likelihood functions',
#  'logarithms',
#  'logit and probit models',
#  'long-run elasticity',
#  'long-run propensity (LRP)',
#  'longitudinal data',
#  'loss functions',
#  'lunch program and math performance',
#  'macroeconomists',
#  'main discussion',
#  'main discussion',
#  'marginal effect',
#  'marital status',
#  'martingale difference sequence',
#  'martingale functions',
#  'matched pair samples',
#  'math performance and lunch program',
#  'mathematical statistics',
#  'matrices',
#  'matrix notation',
#  'maximum likelihood estimation',
#  'maximum likelihood estimation of',
#  'mean absolute error (MAE)',
#  'mean independence',
#  'measurement error',
#  'measures of association',
#  'measures of central tendency',
#  'measures of variability',
#  'median',
#  'men, return to education',
#  'method of moments approach',
#  'micronumerosity',
#  'military personnel survey, oversampling in',
#  'minimum variance unbiased estimators',
#  'minimum wages',
#  'minorities and loans',
#  'missing data',
#  'misspecification',
#  'motherhood, teenage',
#  'moving average process of order one',
#  'multicollinearity',
#  'multiple hypotheses tests',
#  'multiple regression analysis',
#  'multiple restrictions',
#  'multiple-step-ahead forecasts',
#  'multiplicative measurement error',
#  'multivariate normal distribution',
#  'municipal bond interest rates',
#  'murder rates',
#  'n-R-squared statistic',
#  'natural experiments',
#  'natural logarithms',
#  'netting out',
#  'no perfect collinearity assumption',
#  'no serial correlation assumption',
#  'nominal dollars',
#  'nonexperimental data',
#  'nonlinear functions',
#  'nonlinearities, incorporating in simple regressions,  ',
#  'nonnested models',
#  'nonrandom samples',
#  'nonstationary time series processes',
#  'normal distribution',
#  'normal sampling distributions',
#  'normality assumption',
#  'normality of OLS, asymptotic',
#  'normality of errors assumption',
#  'normality of estimators in general, asymptotic,  ',
#  'null hypothesis',
#  'observational data',
#  'omitted variable bias',
#  'one-sided alternatives',
#  'one-step-ahead forecasts',
#  'one-tailed tests',
#  'online databases',
#  'online search services',
#  'order condition',
#  'ordinal variables',
#  'ordinary least squares',
#  'out-of-sample criteria',
#  'outliers',
#  'over controlling',
#  'overall significance of regressions',
#  'overdispersion',
#  'overidentified equations',
#  'overidentifying restrictions, testing',
#  'overspecifying the model',
#  'overview',
#  'overview',
#  'p-values',
#  'pairwise uncorrelated random variables',
#  'panel data',
#  'panel data (continued)',
#  'quadratic form for matrices',
#  'quadratic functions',
#  'quadratic time trends',
#  'qualitative information',
#  'quantile regression',
#  'quasi- (natural) experiments',
#  'quasi-demeaned data',
#  'quasi-differenced data',
#  'quasi-likelihood ratio statistic',
#  'quasi-maximum likelihood estimation (QMLE),  ',
#  'race',
#  'random coefficient model',
#  'random effects',
#  'random sampling',
#  'random slope model',
#  'random variables',
#  'random vectors',
#  'random walks',
#  'rank condition',
#  'rank of matrix',
#  'rational distributed lag models',
#  'real dollars',
#  'recidivism, duration analysis',
#  'reduced form equations',
#  'regressands',
#  'regression analysis',
#  'regression analysis; simple regression model; ',
#  'regression specification error test (REST)',
#  'regressors',
#  'rejection region',
#  'rejection rule',
#  'relative change',
#  'relative efficiency',
#  'relevant variables, excluding',
#  'reporting multiple regression results',
#  'resampling methods, defined',
#  'rescaling',
#  'residual analysis',
#  'residual sum of squares (SSR)',
#  'residuals',
#  'residuals',
#  'response probability',
#  'response variables',
#  'restricted model',
#  'retrospective data',
#  'returns on equity and CEO salaries',
#  'robust regression',
#  'rooms and housing prices',
#  'root mean squared error (RMSE)',
#  'row vectors',
#  'salaries',
#  'sales',
#  'sales tax increase',
#  'sample average',
#  'sample correlation coefficient',
#  'sample covariance',
#  'sample regression function (SRF)',
#  'sample selection corrections',
#  'sample standard deviation',
#  'sample variation in the explanatory variable ',
#  'sampling distributions',
#  'sampling standard deviation',
#  'sampling variances',
#  'sampling, nonrandom',
#  'savings',
#  'savings and income',
#  'scalar multiplication',
#  'scalar variance-covariance matrices',
#  'scatterplot',
#  'scatterplots',
#  'school lunch program and math performance',
#  'school size and student performance',
#  'score statistic',
#  'scrap rates and job training',
#  'seasonality',
#  'selected samples',
#  'self-selection problems',
#  'semi-elasticity',
#  'sensitivity analysis',
#  'sequential exogeneity',
#  'serial correlation',
#  'serial correlation-robust',
#  'serial correlation-robust standard errors',
#  'short-run elasticity',
#  'significance level',
#  'simple equation',
#  'simple regression model',
#  'simultaneous equations models',
#  'skewness',
#  'sleeping vs. working',
#  'slopes',
#  'smearing estimates',
#  'smoking',
#  'soybean yields and fertilizers',
#  'spreadsheets',
#  'spurious regression',
#  'square matrices',
#  'squares)',
#  'stable AR(1) processes',
#  'standard deviation',
#  'standard error of the regression (SER)',
#  'standard errors',
#  'standard normal distribution',
#  'standardized coefficients',
#  'standardized random variables',
#  'standardized test scores',
#  'static Phillips curve',
#  'static models',
#  'stationary time series processes',
#  'statistical inference',
#  'statistical significance',
#  'statistical tables',
#  'statistics',
#  'stepwise regression',
#  'stochastic processes',
#  'stock prices and trucking regulations',
#  'stock returns',
#  'stratified sampling',
#  'strict exogeneity assumption',
#  'strict stationarity',
#  'strictly exogenous variables',
#  'strongly dependent time series',
#  'structural equations',
#  'student enrollment, t test',
#  'student performance',
#  'studentized residuals',
#  'style hints for empirical papers',
#  'sum of squared residuals',
#  'summation operator',
#  'supply shock',
#  'symmetric matrices',
#  'system estimation methods',
#  'systematic part, defined',
#  't distribution',
#  't distribution for standardized estimators',
#  't statistics',
#  't tests',
#  'tables, statistical',
#  'tax exemption',
#  'teachers, salary-pension tradeoff',
#  'teenage motherhood',
#  'tenure',
#  'test scores',
#  'test scores, as indicators of ability',
#  'test statistics',
#  'testing for',
#  'text files and editors',
#  'theorems',
#  'theoretical framework',
#  'three stage least squares',
#  'time series data',
#  'time trends',
#  'time-demeaned data',
#  'time-varying error',
#  'top coding',
#  'total sample variation in xj',
#  'total sum of squares (SST)',
#  'trace of matrix',
#  'traffic fatalities',
#  'training grants',
#  'transpose of matrix',
#  'treatment group',
#  'trend-stationary processes',
#  'trends',
#  'trucking regulations and stock prices',
#  'true model, defined',
#  'truncated regression models',
#  'two stage least squares',
#  'two-period panel data',
#  'two-sided alternatives',
#  'two-tailed tests',
#  'two-variable linear regression model',
#  'u (“unobserved” term)',
#  'unanticipated inflation',
#  'unbalanced panels',
#  'unbiased estimation of s2',
#  'unbiasedness',
#  'uncentered R-squareds',
#  'unconditional forecasts',
#  'uncorrelated random variables',
#  'underspecifying the model',
#  'unemployment',
#  'unidentified equations',
#  'unit roots',
#  'units of measurement, effects of changing, ',
#  'universities vs. junior colleges',
#  'unobserved effects/heterogeneity',
#  'unrestricted model',
#  'unsystematic part, defined',
#  'upward bias',
#  'utility maximization',
#  'variables',
#  'variables; specific types',
#  'variance inflation factor (VIF)',
#  'variance of prediction error',
#  'variance-covariance matrices',
#  'variances',
#  'vector autoregressive model',
#  'vectors, defined',
#  'veterans, earnings of',
#  'voting outcomes',
#  'weak instruments',
#  'weakly dependent time series',
#  'wealth',
#  'weighted least squares estimation',
#  'when assumed heteroskedasticity function is wrong, ',
#  'when heteroskedasticity function must be estimated, ',
#  'when heteroskedasticity is known up to a ',
#  'with different slopes',
#  'with interacting terms',
#  'with log(y) dependent variable',
#  'with multiple dummy variables',
#  'with ordinal variables',
#  'with qualitative information',
#  'with unobservables, general approach',
#  'with unobservables, using proxy',
#  'within estimators',
#  'women in labor force',
#  'women’s fertility',
#  'work',
#  'worker compensation laws and weeks out of  ',
#  'worker productivity',
#  'working individuals in 1976',
#  'working vs. sleeping',
#  'working women',
#  'writing empirical papers',
#  'year dummy variables',
#  'zero conditional mean assumption',
#  'zero mean and zero correlation assumption']

# %%
df = pd.DataFrame({'ID': [i for i in range(len(total_extracted_key_phrase))],
            'phrase': sorted(total_extracted_key_phrase),
            'textbook': ['Wooldridge - Introductory Econometrics' for _ in range(len(total_extracted_key_phrase))],
            'definition_or_explanations': ['' for _ in range(len(total_extracted_key_phrase))]})

# %%
df.head()
# Out:
#    ID                             phrase  \
# 0   0                               2SLS
# 1   1                       401(k) plans
# 2   2                 AFDC participation
# 3   3  AR(1) models, consistency example
# 4   4           AR(1) serial correlation
#
#                                  textbook definition_or_explanations
# 0  Wooldridge - Introductory Econometrics
# 1  Wooldridge - Introductory Econometrics
# 2  Wooldridge - Introductory Econometrics
# 3  Wooldridge - Introductory Econometrics
# 4  Wooldridge - Introductory Econometrics

# %%
df.to_csv('Wooldridge_extracted_phrases.csv', index=False)
